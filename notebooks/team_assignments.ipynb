# %%
from ortools.linear_solver import pywraplp
import pandas as pd

# %%
# MAKE SURE THAT THE FORM HAS BEEN EMPTIED FIRST.
# MAKE SURE THAT THE HEADER HAVE BEEN CLEANED-UP.
raw_data = pd.read_csv('/Users/sahuguet/Downloads/NYUAD-demo.csv', header=1)

raw_data[0:5]
# Out:
#           ResponseID           ResponseSet            StartDate  \
# 0  R_30x9Uwhs6nzg7jR  Default Response Set  2016-04-15 08:18:57
# 1  R_x3LrSGQNyflcl7X  Default Response Set  2016-04-15 08:18:50
# 2  R_QgYh7SqqGS4E9mp  Default Response Set  2016-04-15 08:18:49
# 3  R_AiKdCU7j1jlJrzz  Default Response Set  2016-04-15 08:22:44
# 4  R_RUiyKZ2TcqNuFON  Default Response Set  2016-04-15 08:20:53
#
#                EndDate  Finished  nyuad-logo  \
# 0  2016-04-15 08:19:31         1           1
# 1  2016-04-15 08:20:26         1           1
# 2  2016-04-15 08:24:04         1           1
# 3  2016-04-15 08:24:23         1           1
# 4  2016-04-15 08:24:55         1           1
#
#    Please indicate the project(s) you want to work on        Your name  \
# 0                                                  1        Quan Vuong
# 1                                                  1     Qandeel Tariq
# 2                                                  1   Lingliang Zhang
# 3                                                  1     Hazem Ibrahim
# 4                                                  1      Matthew Volk
#
#    Your gender  Are you an international participant?     ...       \
# 0            1                                      2     ...
# 1            2                                      1     ...
# 2            1                                      2     ...
# 3            1                                      2     ...
# 4            1                                      1     ...
#
#    Please rank the projects (top = most preferred)-ClimateViz  \
# 0                                                 11
# 1                                                  6
# 2                                                  4
# 3                                                  3
# 4                                                  6
#
#    Please rank the projects (top = most preferred)-Celebreat  \
# 0                                                 10
# 1                                                  3
# 2                                                  5
# 3                                                 10
# 4                                                 11
#
#    Please rank the projects (top = most preferred)-Fahmt  \
# 0                                                  1
# 1                                                  1
# 2                                                  1
# 3                                                 15
# 4                                                  1
#
#    Please rank the projects (top = most preferred)-Tindercise  \
# 0                                                  6
# 1                                                  2
# 2                                                 13
# 3                                                  8
# 4                                                 15
#
#    Please rank the projects (top = most preferred)-Tasaka  \
# 0                                                 13
# 1                                                 11
# 2                                                  6
# 3                                                 14
# 4                                                 12
#
#    Please rank the projects (top = most preferred)-Sadiki  \
# 0                                                  8
# 1                                                 10
# 2                                                  8
# 3                                                 12
# 4                                                 13
#
#    Please rank the projects (top = most preferred)-Beacon Manara  \
# 0                                                  4
# 1                                                  5
# 2                                                 15
# 3                                                 11
# 4                                                  5
#
#    Please rank the projects (top = most preferred)-VR Refugees  \
# 0                                                  7
# 1                                                 15
# 2                                                 12
# 3                                                  7
# 4                                                  8
#
#    Please rank the projects (top = most preferred)-Protector  Unnamed: 28
# 0                                                 14                  NaN
# 1                                                  8                  NaN
# 2                                                  9                  NaN
# 3                                                 13                  NaN
# 4                                                  4                  NaN
#
# [5 rows x 29 columns]

# %%
STUDENTS = raw_data['Your name']
data = raw_data.set_index('Your name')
GENDER = data['Your gender'] -1
INTERNATIONAL = data['Are you an international participant?'] -1
NOT_UAE = (data['Are you from the UAE?'] -1) / 2
NOT_NYU_AD = (data['Are you from NYU AD?'] -1) / 2
NO_SKILLS = data['Do you consider yourself an experienced developer?'] -1

PROJECTS = raw_data.columns[13:28] # We limit the number of projects.

SCORING = { 1:1, 2:100, 3:150}
SCORING.update({ i:156+i for i in range(4,25)})

# %%
NOT_UAE.sum()
# Out:
# 49.0

# %%
#STUDENTS = pd.concat([STUDENTS[0:72], STUDENTS[76:76]])
STUDENTS = STUDENTS

# Average number of students.
RATIO = int(len(STUDENTS)/len(PROJECTS)) + 1
print ("Avg team size: %d " % RATIO)
NO_SKILLS
print (len(STUDENTS))
# Out:
# Avg team size: 6
# 87

# %%
solver = pywraplp.Solver('StudentProjectGridCBC', pywraplp.Solver.CBC_MIXED_INTEGER_PROGRAMMING)
#solver = pywraplp.Solver('StudentProjectGridCBC', pywraplp.Solver.GLPK_MIXED_INTEGER_PROGRAMMING)

matches = {}
for student in STUDENTS:
    for project in PROJECTS:
        matches[student, project] = solver.IntVar(0, 1, 'matches[%s,%s]' % (student, project))
        
z = solver.Sum([SCORING[data[project][student]] *  matches[student, project]
                 for student in STUDENTS
                 for project in PROJECTS])


######################
#### Constraints #####
######################

# One person per project
for student in STUDENTS:
    solver.Add(solver.Sum([matches[student, project] for project in PROJECTS]) == 1)

# At least one international student per project
for project in PROJECTS:
    solver.Add(solver.Sum([matches[student, project] * (1-INTERNATIONAL[student]) for student in STUDENTS]) >= 1)

# No more than xx NYU AD students
for project in PROJECTS:
    solver.Add(solver.Sum([matches[student, project] * (1 - NOT_NYU_AD[student]) for student in STUDENTS]) <= 4)

# No more than xx UAE students
for project in PROJECTS:
    solver.Add(solver.Sum([matches[student, project] * (1 - NOT_UAE[student]) for student in STUDENTS]) <= 3)

# Good gender diversity
for project in PROJECTS:
    solver.Add(solver.Sum([matches[student, project] * GENDER[student] for student in STUDENTS]) >= 2)

# Enough skills in the team
for project in PROJECTS:
    solver.Add(solver.Sum([matches[student, project] * (1-NO_SKILLS[student]) for student in STUDENTS]) >= 1)

# Good size balance: more than 2 and less than RATIO.
for project in PROJECTS:
    solver.Add(solver.Sum([matches[student, project] for student in STUDENTS]) >= 3)
    solver.Add(solver.Sum([matches[student, project] for student in STUDENTS]) <= RATIO)
    
#solver.Add(solver.Sum([matches[student, 'Cityzoom'] for student in STUDENTS]) == 7)
    
# Hardcoded assignments for students.
# hard_coded_assignments = {"Tareq si salem": "Crowd Manager", "Rawan ELJAMAL": "Crowd Manager"}
for student in STUDENTS:
    continue
    if student in hard_coded_assignments:
        solver.Add(matches[student, hard_coded_assignments[student]] == 1)

# %%
objective = solver.Minimize(z)
solver.Solve()
s = solver.Objective().Value()
s
# Out:
# 3244.0

# %%
BUCKETS = {}
for project in PROJECTS:
    BUCKETS[project] = []

ASSIGNMENT = 0
for student in STUDENTS:
    for project in PROJECTS:
        if int(matches[student, project].SolutionValue()):
            student_name = student
            if INTERNATIONAL[student] == 0:
                student_name += '-*'
            if GENDER[student] == 1:
                student_name += '-F'
            if NOT_NYU_AD[student] == 0:
                student_name += '-nyu'
            if NOT_UAE[student] == 0:
                student_name += '-uae'
            if NO_SKILLS[student] == 0:
                student_name += '-xp'
            student_name += " (%d)" % data[project][student]
            BUCKETS[project].append(student_name)
            ASSIGNMENT += 1

for bucket in BUCKETS:
    people = BUCKETS[bucket]
    print ("%s (%d)" % (bucket, len(people)))
    print (BUCKETS[bucket])
    print
    
    
print (len(BUCKETS), 'projects.')
# Out:
# Please rank the projects (top = most preferred)-Arabic reCaptcha (6)
# ['Khalid AlAwar-uae-xp (1)', 'Samr Samir Ali-F-uae-xp (1)', 'Ali Senhaji (1)', 'Rana Abul-Haija-*-F-xp (1)', 'Katia-F (1)', 'Muhammed Al Sayadi-uae-xp (1)']
# Please rank the projects (top = most preferred)-Crowd Manager (6)
# ['Rawan ELJAMAL-F (1)', 'Prasant-*-nyu-uae (1)', 'wasi-uae-xp (1)', 'Hanan Hadad-F-uae (1)', 'Rawane eljamal -F (1)', 'Jane Choe-F (1)']
# Please rank the projects (top = most preferred)-Smart Fork (6)
# ['Amira Gamal-F-xp (1)', 'ImadEddine Toubal-xp (1)', 'Tareq si salem-xp (1)', 'CHORFI IHEB-*-xp (1)', 'Shouq Darwish-F-uae-xp (1)', 'Leanne-F-uae (1)']
# Please rank the projects (top = most preferred)-Maktabi (6)
# ['Ali Aldarwish-uae-xp (1)', 'Kyle Dhillon-* (1)', 'Sara Al Kendi-F-uae (1)', 'Alaa Daffalla-F (1)', 'Nadine Handal-F (1)', 'Jomana jamal obaida-*-F (1)']
# Please rank the projects (top = most preferred)-DiploMap (6)
# ['Paula Dozsa-F-nyu-uae (1)', 'William-nyu-uae (3)', 'Wafa Waheeda Syed-*-F-xp (2)', 'Terri Burns-*-F (1)', 'Manel Loubna Omani-F-xp (1)', 'Batu-nyu-uae (1)']
# Please rank the projects (top = most preferred)-Mindy (6)
# ['Hazem Ibrahim-nyu (1)', 'Lama Ahmad-F-nyu-uae (1)', 'Nuzla Ismail-*-F (2)', 'Alaa El Hariri -F (1)', 'Ansari Othmane-xp (1)', 'Muaz Ahmad-nyu-uae-xp (2)']
# Please rank the projects (top = most preferred)-ClimateViz (6)
# ['Ankit Gupta-*-xp (1)', 'Muhammad Shujaat Mirza-nyu-xp (1)', 'Mahmoud Magdi Abdulhamid-* (1)', 'Yana-F-nyu-uae (1)', 'Guyu-nyu-uae-xp (1)', 'Nahil Memon-F-nyu-uae (1)']
# Please rank the projects (top = most preferred)-Celebreat (6)
# ['Alexandru Grigoras-*-xp (4)', 'youssouf bqhq eddine-xp (3)', 'Sara Alarifi-F (1)', 'Ahmed mahmoud abdulhamid-uae (1)', 'Shehroze Khan-nyu-uae-xp (1)', 'Balsam-F-uae (1)']
# Please rank the projects (top = most preferred)-Fahmt (6)
# ['Quan Vuong-nyu (1)', 'Qandeel Tariq-*-F (1)', 'Lingliang Zhang-nyu-uae-xp (1)', 'William Held -nyu-uae (1)', 'Lilly Wang-*-F (1)', 'Emrehan-* (1)']
# Please rank the projects (top = most preferred)-Tindercise (5)
# ['Lavine-*-F (1)', 'BENAOUALI Lamia-F-xp (2)', 'Yomna Omar (AUS)-F-uae-xp (1)', 'Abdulrahman Osoble-uae-xp (2)', 'Abdullah Ibrahim-uae (2)']
# Please rank the projects (top = most preferred)-Tasaka (6)
# ['Joyce Zhang-*-F (3)', 'Mariam F-F-uae (1)', 'Moutaz-uae (1)', 'Athra-F-uae (1)', 'Hanan tbaileh-F (1)', 'Musab Ahmed Popatia-xp (9)']
# Please rank the projects (top = most preferred)-Sadiki (6)
# ['Omar Abdullah-uae (1)', 'Gonzalo Beviglia-*-xp (1)', 'Hananah Ghibeh-F-uae (1)', 'Zuhair Alsader-xp (1)', 'Harini Kannan-*-F-xp (1)', 'Nizar Hawawreh (1)']
# Please rank the projects (top = most preferred)-Beacon Manara (4)
# ['Saeed Motamed-uae-xp (2)', 'Hend Darwish-F (2)', 'Saif ur Rehman muhammad yousuf-uae-xp (2)', 'Rosy Guptq-*-F-xp (4)']
# Please rank the projects (top = most preferred)-VR Refugees (6)
# ['Alejandra Trejo Rodriguez-F-nyu-uae (5)', 'Hayat AlHassan-F-nyu-uae (7)', 'khalid machchate (3)', 'Shubham Gupta-* (3)', 'Mohammad hutaib-uae (7)', 'Mohamed Hashim-xp (1)']
# Please rank the projects (top = most preferred)-Protector (6)
# ['Matthew Volk-*-xp (4)', 'Sarah Fakhoury-F-xp (2)', 'Ohoud Al-Shawkani-F (2)', 'Randa Abuali-F-uae (2)', 'Mohamed Gamal-xp (1)', 'Diala-F-uae (2)']
# 15 projects.
